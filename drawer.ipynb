# %%
include("diffpackage.jl")
# Out:
# Main.DiffPackage

# %%
using Plots
using .DiffPackage

# %%
# Parameter is the number of intervals
# This version uses built-in julia methods to solve equation
X, Y = solve_matrix_fem(150)
# Out:
# (0.0:0.01:2.0, [60.54054054052979, 60.13513513512448, 59.72972972971917, 59.32432432431385, 58.918918918908545, 58.513513513503256, 58.10810810809792, 57.70270270269265, 57.29729729728736, 56.891891891882054  …  1.5540540540538266, 1.3513513513511552, 1.1486486486484613, 0.9459459459458077, 0.7432432432431363, 0.5405405405404647, 0.33783783783778426, 0.1351351351351173, 0.0, 0.0])

# %%
plot(X, Y)

# %%
# Parameter is the number of intervals
# This version uses thomas algorithm to solve equation
X, Y = solve_thomas_fem(1200)
# Out:
# (0.0:0.01:2.0, [60.23742677029341, 59.835052502590536, 59.432678234887575, 59.0303039671844, 58.62792969948126, 58.225555431778254, 57.82318116407547, 57.4208068963723, 57.01843262866936, 56.61605836096685  …  1.6910179640701857, 1.4898203592799653, 1.2886227544897437, 1.0874251496995229, 0.8862275449093023, 0.6850299401190827, 0.4838323353288638, 0.2826347305386451, 0.08143712574842622, 0.0])

# %%
plot(X, Y)
